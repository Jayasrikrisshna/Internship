# %%
#Q1 python program to scrape data for “Data Analyst” Job position in “Bangalore” location


import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service


driver = webdriver.Chrome(r'C:\Users\Jayasri\Downloads\chromedriver_win32\chromedriver.exe')
driver = webdriver.Chrome('chromedriver.exe')

url='http://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element(By.CLASS_NAME ,"suggestor-input ")

search_job.send_keys("Data Analyst")

search_locn = driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")

search_locn.send_keys("Banglore")

search_btn = driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[6]")

search_btn.click()

# %%
title_tags = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')

job_titles = []

for i in title_tags:
    job_titles.append(i.text)
    
company_name = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')

companies = []

for i in company_name:
    companies.append(i.text)
    
exp_tags = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')


experience = []

for i in exp_tags:
    experience.append(i.text)
    
locn_tags = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')

location = []
for i in locn_tags:
    location.append(i.text)
    
jobs=pd.DataFrame()
jobs['Job Title'] = job_titles
jobs['Company Name'] = companies
jobs['Experience'] = experience
jobs['Location'] = location
jobs[0:10]
# Out:
#                                      Job Title  \
# 0                     Sr.Business Data Analyst
# 1                  Data Analyst - CRM Platform
# 2     Software Technical Expert - Data Analyst
# 3                       Reference Data Analyst
# 4                           Sales Data Analyst
# 5                                 Data Analyst
# 6  Hiring Data Analyst - Forensics, KPMG India
# 7                                 Data Analyst
# 8                             Big data analyst
# 9             Data Analyst/Senior Data Analyst
#
#                       Company Name Experience  \
# 0                        Collabera   6-11 Yrs
# 1                Artech infosystem    1-6 Yrs
# 2               Schneider Electric    3-6 Yrs
# 3                    Deutsche Bank    2-5 Yrs
# 4             NUANCE INDIA PVT LTD    1-3 Yrs
# 5                        Clarivate    2-4 Yrs
# 6                       KPMG India    2-6 Yrs
# 7                              Jio   8-11 Yrs
# ...

# %%
#Q2 a python program to scrape data for “Data Scientist” Job position in “Bangalore” location

import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service


driver = webdriver.Chrome(r'C:\Users\Jayasri\Downloads\chromedriver_win32\chromedriver.exe')
driver = webdriver.Chrome('chromedriver.exe')

url='http://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element(By.CLASS_NAME ,"suggestor-input ")

search_job.send_keys("Data Scientist")

search_locn = driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")

search_locn.send_keys("Banglore")

search_btn = driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[6]")

search_btn.click()

# %%
title_tags = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')

job_titles = []

for i in title_tags:
    job_titles.append(i.text)
    
company_name = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')

companies = []

for i in company_name:
    companies.append(i.text)
    
exp_tags = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')


experience = []

for i in exp_tags:
    experience.append(i.text)
    
locn_tags = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')

location = []
for i in locn_tags:
    location.append(i.text)
    
jobs=pd.DataFrame()
jobs['Job Title'] = job_titles
jobs['Company Name'] = companies
jobs['Experience'] = experience
jobs['Location'] = location
jobs[0:10]
# Out:
#                                            Job Title       Company Name  \
# 0  Urgent Job Opening For AI Practitioner - Data ...              Wipro
# 1                                 Dataiku Consultant              Wipro
# 2  Opportunity For Data Scientist - Female Candid...               PayU
# 3                                     Data Scientist              Wipro
# 4            Research and Development -AI/ML -(PhD )                EXL
# 5                       Senior Data Science Engineer  Fractal Analytics
# 6                 Data Science - Engineering Manager              Paytm
# 7                                     Data Scientist                UPL
# 8          Data Scientist- Assistant Manager/Manager            Genpact
# 9                                     Data Scientist                IBM
#
#   Experience                                           Location
# 0  11-21 Yrs  Kochi/Cochin, New Delhi, Bangalore/Bengaluru, ...
# ...

# %%
#Q3 Scrap data Using filters

import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service


driver = webdriver.Chrome(r'C:\Users\Jayasri\Downloads\chromedriver_win32\chromedriver.exe')
driver = webdriver.Chrome('chromedriver.exe')

url='http://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element(By.CLASS_NAME ,"suggestor-input ")

search_job.send_keys("Data Scientist")


search_btn = driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[3]/div/div/div[6]")

search_btn.click()

# %%
salary_check = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[6]/div[2]/div[2]/label/i")
salary_check.click()

# %%
location_check = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[6]/div[2]/div[3]")
location_check.click()

# %%
title_tags = driver.find_elements(By.XPATH,'//a[@class = "title fw500 ellipsis"]')

job_titles = []

for i in title_tags:
    job_titles.append(i.text)
    
company_name = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')

companies = []

for i in company_name:
    companies.append(i.text)
    
exp_tags = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')


experience = []

for i in exp_tags:
    experience.append(i.text)
    
locn_tags = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')

location = []
for i in locn_tags:
    location.append(i.text)
    
jobs=pd.DataFrame()
jobs['Job Title'] = job_titles
jobs['Company Name'] = companies
jobs['Experience'] = experience
jobs['Location'] = location
jobs[0:10]
# Out:
#                                Job Title  \
# 0        DigitalBCG GAMMA Data Scientist
# 1        Senior Associate - Data Science
# 2       Data Scientist - Noida/Bangalore
# 3   Data Scientist - Machine learning AI
# 4         Data Scientist - MIND Infotech
# 5                         Data Scientist
# 6                         Data Scientist
# 7  Data Scientist - Predictive Analytics
# 8      Data Scientist - Engine Algorithm
# 9                         Data Scientist
#
#                                Company Name Experience  \
# 0                   Boston Consulting Group    2-5 Yrs
# 1                Black Turtle India Pvt Ltd    4-7 Yrs
# 2                                       EXL   5-10 Yrs
# 3                             Teq Analytics    3-8 Yrs
# 4  MOTHERSONSUMI INFOTECH & DESIGNS LIMITED    4-8 Yrs
# 5   Mount Talent Consulting Private Limited    2-4 Yrs
# 6   Mount Talent Consulting Private Limited    2-4 Yrs
# 7                              Confidential    1-6 Yrs
# ...

# %%
#Q4 : Scrape data of first 100 sunglasses listings on flipkart.com


import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service


driver = webdriver.Chrome(r'C:\Users\Jayasri\Downloads\chromedriver_win32\chromedriver.exe')
driver = webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

url='https://www.flipkart.com/'
driver.get(url)

# %%
close_btn = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')
close_btn.click()

# %%
search_thing = driver.find_element(By.CLASS_NAME ,"_3704LK")

search_thing.send_keys("Sunglasses")

# %%
search_btn = driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')

search_btn.click()

# %%
page = []
url1 = driver.find_elements(By.XPATH,'//div[@class="_2MImiq"]//a')
for i in url1:
    page.append(i.get_attribute("href"))
page
# Out:
# ['https://www.flipkart.com/search?q=Sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1',
#  'https://www.flipkart.com/search?q=Sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2',
#  'https://www.flipkart.com/search?q=Sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3',
#  'https://www.flipkart.com/search?q=Sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4',
#  'https://www.flipkart.com/search?q=Sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5',
#  'https://www.flipkart.com/search?q=Sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6',
#  'https://www.flipkart.com/search?q=Sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7',
# ...

# %%
brands = []
price = []
description = []
discount = []
for i in page[:3]:
    driver.get(i)
    
    brand_tag = driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    for j in brand_tag[:40]:
        brands.append(j.text)
    
    des_tag = driver.find_elements(By.XPATH,"//div[@class='_2B099V']/a")
    for b in des_tag[:80]:
        description.append(b.text)
        
    pri = driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")
    for p in pri[:40]:
        price.append(p.text)
    
    disc = driver.find_elements(By.XPATH,"//div[@class='_3Ay6Sb']/span")
    for d in disc[:40]:
        discount.append(d.text)
len(discount)
# Out:
# 120

# %%
D=description[::2]
D
    
len(D)
# Out:
# 120

# %%
sunglass = pd.DataFrame({})
sunglass['Brands']=brands[:100]
sunglass['Price']=price[:100]
sunglass['Description']=D[:100]
sunglass['Discount']=discount[:100]
sunglass
# Out:
#             Brands Price                                        Description  \
# 0     Singco India  ₹598  Gradient, Toughened Glass Lens, UV Protection ...
# 1     Silver Kartz  ₹313           UV Protection Clubmaster Sunglasses (53)
# 2         DAHAAZIL  ₹177  UV Protection, Night Vision, Riding Glasses Wa...
# 3         Fastrack  ₹639   UV Protection Rectangular Sunglasses (Free Size)
# 4        New Specs  ₹264   UV Protection Rectangular Sunglasses (Free Size)
# ..             ...   ...                                                ...
# 95  ROZZETTA CRAFT  ₹399  UV Protection, Gradient Rectangular Sunglasses...
# 96      PHENOMENAL  ₹339         UV Protection Retro Square Sunglasses (53)
# 97           NuVew  ₹275  UV Protection, Night Vision, Riding Glasses Sp...
# 98      PHENOMENAL  ₹369  UV Protection Retro Square Sunglasses (Free Size)
# 99  ROZZETTA CRAFT  ₹399  UV Protection, Gradient Round Sunglasses (Free...
#
#    Discount
# 0   80% off
# 1   79% off
# 2   82% off
# ...

# %%
#Q5 Scrape 100 reviews data from flipkart.com for iphone11 phone

import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service

driver = webdriver.Chrome(r'C:\Users\Jayasri\Downloads\chromedriver_win32\chromedriver.exe')
driver = webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

url='https://www.flipkart.com/'
driver.get(url)

# %%
close_btn = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')
close_btn.click()

# %%
search_thing = driver.find_element(By.CLASS_NAME ,"_3704LK")

search_thing.send_keys("iphone 11")

# %%
search_btn = driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')

search_btn.click()

# %%
page = []
url1 = driver.find_elements(By.XPATH,'//div[@class="_2kHMtA"]//a')
for i in url1[:1]:
    page.append(i.get_attribute("href"))
page
# Out:
# ['https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSUPVRTR&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=1041ddc6-4f8d-48e3-bf55-4f5a5167585f.MOBFWQ6B7KKRXDDS.SEARCH&ppt=hp&ppn=homepage&ssid=r9po3lxaxc0000001657623260432&qH=f6cdfdaa9f3c23f3']

# %%
url2 = 'https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSUPVRTR&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=14957251-0fde-4847-a29e-e72e2acec7cc.MOBFWQ6B7KKRXDDS.SEARCH&ppt=hp&ppn=homepage&ssid=dvkm9iafj40000001657594148925&qH=f6cdfdaa9f3c23f3'
driver.get(url2)

# %%
allreview_btn= driver.find_element(By.XPATH,"//div[@class='_3UAT2v _16PBlm']")
allreview_btn.click()

# %%
page2 = []
url2 = driver.find_elements(By.XPATH,'//nav[@class="yFHi8N"]//a')[:11]

for i in url2:
    page2.append(i.get_attribute("href"))
page2
# Out:
# ['https://www.flipkart.com/apple-iphone-11-white-128-gb/product-reviews/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSUPVRTR&marketplace=FLIPKART&page=1',
#  'https://www.flipkart.com/apple-iphone-11-white-128-gb/product-reviews/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSUPVRTR&marketplace=FLIPKART&page=2',
#  'https://www.flipkart.com/apple-iphone-11-white-128-gb/product-reviews/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSUPVRTR&marketplace=FLIPKART&page=3',
#  'https://www.flipkart.com/apple-iphone-11-white-128-gb/product-reviews/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSUPVRTR&marketplace=FLIPKART&page=4',
#  'https://www.flipkart.com/apple-iphone-11-white-128-gb/product-reviews/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSUPVRTR&marketplace=FLIPKART&page=5',
# ...

# %%
rating = []
summary = []
full = []

for j in page2:
    driver.get(j)
    rate = driver.find_elements(By.XPATH,"//div[@class='_3LWZlK _1BLPMq']")
    for i in rate:
        rating.append(i.text)
    sum_tag = driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']")
    for i in sum_tag:
        summary.append(i.text)
    full_rev = driver.find_elements(By.XPATH,"//div[@class='t-ZTKy']")
    for i in full_rev:
        full.append(i.text)
len(summary)
# Out:
# 110

# %%
iphone=pd.DataFrame({})
iphone['Rating']=rating[0:100]
iphone['Summary']=summary[0:100]
iphone['Full Review']=full[0:100]
iphone
# Out:
#    Rating              Summary  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       5   Highly recommended
# 4       5    Worth every penny
# ..    ...                  ...
# 95      5               Super!
# 96      5            Wonderful
# 97      5    Worth every penny
# 98      5  Best in the market!
# 99      5            Fabulous!
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   What a camera .....just awesome ..you can feel...
# 4   Previously I was using one plus 3t it was a gr...
# ..                                                ...
# 95  This is my first ever iPhone.\nAnd I truly don...
# 96  Nice value for money good and best price I pho...
# 97  Undoubtedly Iphone 11 is the most successful m...
# ...

# %%
#Q6 Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” 

import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service


driver = webdriver.Chrome(r'C:\Users\Jayasri\Downloads\chromedriver_win32\chromedriver.exe')
driver = webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

url='https://www.flipkart.com/'
driver.get(url)

# %%
close_btn = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')
close_btn.click()

# %%
search_thing = driver.find_element(By.CLASS_NAME ,"_3704LK")

search_thing.send_keys("Sneakers")

# %%
search_btn = driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')

search_btn.click()

# %%
page = []
url1 = driver.find_elements(By.XPATH,'//div[@class="_2MImiq"]//a')
for i in url1:
    page.append(i.get_attribute("href"))
page
# Out:
# ['https://www.flipkart.com/search?q=Sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1',
#  'https://www.flipkart.com/search?q=Sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2',
#  'https://www.flipkart.com/search?q=Sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3',
#  'https://www.flipkart.com/search?q=Sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4',
#  'https://www.flipkart.com/search?q=Sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5',
#  'https://www.flipkart.com/search?q=Sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6',
#  'https://www.flipkart.com/search?q=Sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7',
# ...

# %%
brands = []
price = []
description = []
discount = []
for i in page:
    driver.get(i)
    
    brand_tag = driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    for j in brand_tag:
        brands.append(j.text)
    
    des_tag = driver.find_elements(By.XPATH,"//div[@class='_2B099V']//a[1]")
    for b in des_tag:
        description.append(b.text)
        
    pri = driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")
    for p in pri:
        price.append(p.text)
    
    disc = driver.find_elements(By.XPATH,"//a[@class='_3bPFwb']//div[3]")
    for d in disc:
        discount.append(d.text)
len(discount)
# Out:
# 437

# %%
D=description[::2]
D
# Out:
# ['Stylish and Trendy New Design Lightweight, Breathable S...',
#  'Sneakers For Men',
#  'Modern Trendy Sneakers Shoes Sneakers For Men',
#  'Sneakers Sneakers For Men',
#  'Stylish Comfortable Lightweight, Breathable Walking Sho...',
#  'Sneakers For Men',
#  'Stylish Comfortable Lightweight, Breathable Walking Sho...',
#  'Puma Smash v2 L Sneakers For Men',
#  'Sneakers For Men',
#  'STYLISH MENS BLACK SNEAKER Sneakers For Men',
#  "Original Luxury Branded Fashionable Men's Casual Walkin...",
#  'Sneakers For Men',
#  'Stylish Comfortable Lightweight, Breathable Casual Walk...',
#  'Sneaker Sneakers For Men',
#  'Sneakers Sneakers For Men',
#  'Shark-41 Sneakers For Men',
#  'Casuals, Canvas, Partywear Sneakers For Men',
#  'Casual Sneakers Canvas Shoes For Men Sneakers For Men',
#  'Sports Running Shoes Sneakers For Men',
#  "Casual , Partywear Sneakers Shoes For Men's And Boys Wh...",
#  'Stylish & Trending Outdoor Walking Comfortable Sneakers...',
#  'Sneakers For Men',
# ...

# %%
sneakers = pd.DataFrame({})
sneakers['Brands']=brands[:100]
sneakers['Price']=price[:100]
sneakers['Description']=D[:100]
sneakers['Discount']=discount[:100]
sneakers
# Out:
#                Brands   Price  \
# 0               BIRDE    ₹378
# 1      LOUIS PHILIPPE  ₹2,399
# 2            WOODLAND  ₹2,096
# 3              BRUTON    ₹269
# 4              BRUTON    ₹299
# ..                ...     ...
# 95  STRANGER BROTHERS    ₹496
# 96           RapidBox    ₹650
# 97               NIKE  ₹2,325
# 98       K' Footlance    ₹405
# 99           HOTSTYLE    ₹195
#
#                                           Description Discount
# 0   Stylish and Trendy New Design Lightweight, Bre...  62% off
# 1                                    Sneakers For Men  40% off
# 2       Modern Trendy Sneakers Shoes Sneakers For Men  30% off
# 3                           Sneakers Sneakers For Men  79% off
# 4   Stylish Comfortable Lightweight, Breathable Wa...  76% off
# ..                                                ...      ...
# 95  Men 5014 Latest Collection Stylish Casual Spor...  66% off
# 96  Men's & Boy's Sneaker Blue Shoes Casual Sneake...  34% off
# ...

# %%
#Q8 scrape first 10 laptops data from amazon

driver = webdriver.Chrome(r'C:\Users\Jayasri\Downloads\chromedriver_win32\chromedriver.exe')
driver = webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

url='http://www.amazon.in/'
driver.get(url)

# %%
search_thing = driver.find_element(By.XPATH ,"//input[@class='nav-input nav-progressive-attribute'][@type='text']")

search_thing.send_keys("Laptop")

# %%
search_btn = driver.find_element(By.XPATH,"//input[@class='nav-input nav-progressive-attribute'][@type='submit']")

search_btn.click()

# %%
cpu_filter = driver.find_element(By.XPATH,"//span[text()='Intel Core i7']")
cpu_filter.click()

# %%
title=[]
rating=[]
price = []

title_tag = driver.find_elements(By.XPATH,"//span[@class='a-size-medium a-color-base a-text-normal']")
for i in title_tag[:10]:
    title.append(i.text)
rate_tag = driver.find_elements(By.XPATH,"//div[@class='a-row a-size-small']/span[1]")
for i in rate_tag[:10]:
    rating.append(i.get_attribute("aria-label"))
pri_tag = driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in pri_tag[:10]:
    price.append(i.text)
len(title),len(rating),len(price)
# Out:
# (10, 10, 10)

# %%
Laptop = pd.DataFrame({})
Laptop['Brand']= title
Laptop['Rating']= rating
Laptop['Price']= price
Laptop
# Out:
#                                                Brand              Rating  \
# 0  ASUS TUF Gaming F15 (2021), 15.6" (39.62 cms) ...  4.6 out of 5 stars
# 1  LG Gram 16 Intel Evo 11th Gen i7 Thin & Light ...  4.3 out of 5 stars
# 2  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....  4.3 out of 5 stars
# 3  Lenovo IdeaPad Flex 5 Intel Core i7 11th Gen 1...  4.2 out of 5 stars
# 4  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, I...  4.2 out of 5 stars
# 5  Lenovo IdeaPad Slim 5 Pro Intel Core i7 11th G...  3.8 out of 5 stars
# 6  Hp Pavilion 15 12Th Gen Intel Core I7 16Gb Sdr...  4.0 out of 5 stars
# 7  Acer Nitro 5 Gaming Laptop/12th Gen Intel Core...  4.3 out of 5 stars
# 8  Hp Pavilion X360 11Th Gen Intel Core I7 14 Inc...  4.2 out of 5 stars
# 9  ASUS TUF Dash F15 (2022), 15.6-inch (39.62 cms...  4.1 out of 5 stars
#
#       Price
# 0    89,990
# 1    76,492
# 2    85,499
# 3    86,990
# 4    80,290
# 5    57,890
# 6    75,990
# 7    64,592
# 8    87,900
# 9  1,09,990

# %%
#Q9: Write a python program to scrape data for first 10 job results for Data Scientist Designation in Noida 
#You have to scrape company name, No. of days ago when job was posted, Rating of the company. 
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service


driver = webdriver.Chrome(r'C:\Users\Jayasri\Downloads\chromedriver_win32\chromedriver.exe')
driver = webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

url='https://www.ambitionbox.com/'
driver.get(url)

# %%
job_click=driver.find_element(By.XPATH,"//a[@class='link jobs']")
job_click.click()

# %%
search_job = driver.find_element(By.XPATH ,"//input[@class='input tt-input']")

search_job.send_keys("Data Scientist")


search_btn = driver.find_element(By.XPATH,"//button[@class='ab_btn search-btn round']")

search_btn.click()

# %%
locn_btn = driver.find_element(By.XPATH,"//div[@class='fitler-text'][@title='Location']")
locn_btn.click()

# %%
search_box = driver.find_element(By.XPATH,"//input[@placeholder='Search locations']")
search_box.send_keys("Noida")

# %%
serch_btn = driver.find_element(By.XPATH,"//label[@class='radio-label'][@for='location_Noida']")
serch_btn.click()

# %%
designation = []
company =[]
rating=[]
title_tag = driver.find_elements(By.XPATH,"//a[@class='title noclick']")
for i in title_tag:
    designation.append(i.text)
comp_tag = driver.find_elements(By.XPATH,"//p[@class='company body-medium']")
for i in comp_tag:
    company.append(i.text)
rat_tag = driver.find_elements(By.XPATH,"//span[@class='body-small']")
for i in rat_tag:
    rating.append(i.text)
jobs=pd.DataFrame({})
jobs['Designation']=designation
jobs['Company']=company
jobs['Rating']=rating
jobs
# Out:
#                                          Designation  \
# 0                              Senior Data Scientist
# 1        Data Scientist- Forecasting and R or Python
# 2  Data Scientist - Machine Learning Algorithms (...
# 3  Data Scientist - Machine Learning/Big Data (0-...
# 4  Info Edge - Data Scientist - Machine Learning/...
# 5  Info Edge - Senior Data Scientist - Machine Le...
# 6  LatentBridge - Data Scientist - Python/R (2-6 ...
# 7  Data Science Trainer | AI | Machine Learning |...
# 8  Principal Scientist - Machine Learning - IT (1...
# 9                               Data Scientist - NLP
#
#                                           Company Rating
# 0  Optum Global Solutions (India) Private Limited    4.1
# 1                   GENPACT India Private Limited    4.0
# 2                         Dew Solutions Pvt. Ltd.    4.3
# 3                             InfoEdge India Ltd.    3.9
# 4                         Info Edge India Limited    3.9
# ...

# %%
#Q10 Write a python program to scrape the salary data for Data Scientist designation
#Company name, Number of salaries, Average salary, Minsalary, Max Salary
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service


driver = webdriver.Chrome(r'C:\Users\Jayasri\Downloads\chromedriver_win32\chromedriver.exe')
driver = webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

url='https://www.ambitionbox.com/'
driver.get(url)

# %%
salary_click=driver.find_element(By.XPATH,"//a[@class='link salaries']")
salary_click.click()

# %%
search_job = driver.find_element(By.XPATH ,"//input[@class='tt-input']")
search_job.send_keys("Data Scientist",Keys.ENTER)
search_btn = driver.find_element(By.XPATH,"//div[@class='top-row']")
search_btn.click()

# %%
company=[]
avgsal=[]
minsal=[]
maxsal=[]
exp=[]

comp_name= driver.find_elements(By.XPATH,"//div[@class='company-info']//a")
for j in comp_name:
    company.append(j.text)
avg_sal = driver.find_elements(By.XPATH,"//p[@class='averageCtc']")
for i in avg_sal:
    avgsal.append(i.text)
min_sal=driver.find_elements(By.XPATH,"//div[@class='value body-medium']")
for i in min_sal:
    minsal.append(i.text)
m=minsal[::2]
max_sal=driver.find_elements(By.XPATH,"//div[@class='value body-medium']")
for i in max_sal:
    maxsal.append(i.text)
exp_tag=driver.find_elements(By.XPATH,"//div[@class='sbold-list-header']")
for i in exp_tag:
    exp.append(i.text)
exp
# Out:
# ['3 yrs experience (based on 12 salaries)',
#  '3-4 yrs experience (based on 33 salaries)',
#  '2 yrs experience (based on 15 salaries)',
#  '3-4 yrs experience (based on 32 salaries)',
#  '3-4 yrs experience (based on 21 salaries)',
#  '2-4 yrs experience (based on 89 salaries)',
#  '2-4 yrs experience (based on 51 salaries)',
#  '2-4 yrs experience (based on 57 salaries)',
#  '3-4 yrs experience (based on 21 salaries)',
#  '2-4 yrs experience (based on 69 salaries)']

# %%
maxsal
m2=maxsal[1:20:2]
m2
# Out:
# ['₹ 36.0L',
#  '₹ 26.2L',
#  '₹ 22.0L',
#  '₹ 22.5L',
#  '₹ 26.2L',
#  '₹ 23.0L',
#  '₹ 20.0L',
#  '₹ 21.1L',
#  '₹ 21.0L',
#  '₹ 25.0L']

# %%
jobamb=pd.DataFrame({})
jobamb['Company']=company
jobamb['Avg Salary']=avgsal
jobamb['Min Salary']=m
jobamb['Max Salary']=m2
jobamb['Experience']=exp
jobamb
# Out:
#                                     Company Avg Salary Min Salary Max Salary  \
# 0            Walmart\nData Scientist Salary    ₹ 30.6L    ₹ 25.0L    ₹ 36.0L
# 1           Ab Inbev\nData Scientist Salary    ₹ 20.8L    ₹ 15.0L    ₹ 26.2L
# 2                 ZS\nData Scientist Salary    ₹ 16.7L    ₹ 11.0L    ₹ 22.0L
# 3              Optum\nData Scientist Salary    ₹ 15.9L    ₹ 11.0L    ₹ 22.5L
# 4       Reliance Jio\nData Scientist Salary    ₹ 15.7L     ₹ 5.6L    ₹ 26.2L
# 5  Fractal Analytics\nData Scientist Salary    ₹ 15.5L    ₹ 10.0L    ₹ 23.0L
# 6    Tiger Analytics\nData Scientist Salary    ₹ 14.8L     ₹ 9.0L    ₹ 20.0L
# 7       UnitedHealth\nData Scientist Salary    ₹ 14.0L     ₹ 8.3L    ₹ 21.1L
# 8        EXL Service\nData Scientist Salary    ₹ 13.2L     ₹ 7.6L    ₹ 21.0L
# 9           Deloitte\nData Scientist Salary    ₹ 12.8L     ₹ 7.0L    ₹ 25.0L
#
#                                   Experience
# 0    3 yrs experience (based on 12 salaries)
# ...
